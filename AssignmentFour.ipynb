# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiltabjula/ComputationalMethodsForInformationSystems/blob/master/AssignmentFour.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**INFO5731 Assignment Four**
#
# n this assignment, you are required to conduct topic modeling, sentiment analysis, and regression analysis.
#
#
# #**Question 1: Topic Modeling**
#
#
#
# (30 points).This question is designed to help you understand topic modeling better as well as how to visualize topic modeling results, aims to collect the human meanings of documents. Based on the yelp review data (only the review text will be used for this question), which can be download from Dropbox: https://www.dropbox.com/s/59hsrk56sfwh9u2/Assignment%20four%20data%20Yelp%20%28question%201%20and%202%29.zip?dl=0, select two models and write a python program to identify the top 20 topics (with 15 words for each topic) in the dataset. Before answering this question, please review the materials in lesson 8, as well as the introduction of these models by the links provided.
#
# (1) Labeled LDA (LLDA): https://github.com/JoeZJH/Labeled-LDA-Python
#
# (2) Biterm Topic Model (BTM): https://github.com/markoarnauto/biterm
#
# (3) HMM-LDA: https://github.com/dongwookim-ml/python-topic-model
#
# (4) SupervisedLDA: https://github.com/dongwookim-ml/python-topic-model/tree/master/notebook
#
# (5) Relational Topic Model: https://github.com/dongwookim-ml/python-topic-model/tree/master/notebook
#
# (6) LDA2VEC: https://github.com/cemoody/lda2vec
#
# (7) BERTopic: https://github.com/MaartenGr/BERTopic
#
# (8) LDA+BERT Topic Modeling: https://www.kaggle.com/dskswu/topic-modeling-bert-lda
#
# (9) Clustering for Topic models: (paper: https://arxiv.org/abs/2004.14914), (code: https://github.com/adalmia96/Cluster-Analysis)
#
# The following information should be reported:
#
# (1) Top 20 clusters for topic modeling.
#
# (2) Summarize and describe the topic for each cluster.
#
# (3) Visualize the topic modeling reasults by using pyLDAVis: https://www.machinelearningplus.com/nlp/topic-modeling-visualization-how-to-present-results-lda-models/#14.-pyLDAVis

# %%
import os

from zipfile import ZipFile

zip_file = "/content/Assignment four data Yelp (question 1 and 2).zip"

with ZipFile(zip_file, 'r') as zips:
  zips.extractall()
  print("Done")
# Out:
# Done

# %%
import os
files = os.listdir("/content/Assignment four data Yelp (question 1 and 2)")

# %%
reviews = list()
ratings = list()
user_ids = list()

# %%
import json
for file in files:
  with open('/content/Assignment four data Yelp (question 1 and 2)/'+file,encoding='utf-8') as data:
    json_ip = json.load(data)

    for i in json_ip:
      reviews.append(i['text'])
      ratings.append(i['stars'])
      user_ids.append(i['user_id'])

# %%
import pandas as pd

# %%
df = pd.DataFrame(reviews,columns = ["review"])
df["ratings"] = ratings

# %%
df["user_id"] = user_ids

# %%
df
# Out:
#                                                    review  ...                 user_id
# 0       Awesome service and fantastic food, the wait s...  ...  fRyMK9tELhM1ivYtHP_cYQ
# 1       Seemed pretty pricey to me for what you got......  ...  rdXAuI2fKilcf65W-QoASQ
# 2       We TRIED to go to the buffet on Tuesday eve fo...  ...  6Vj1QBWL2otH8fpk2sP2cw
# 3       Came here for lunch on my 20th birthday and th...  ...  3LMtnGWAFE-Y-jhUlDEq-Q
# 4       Amazing treats - I love their cinnamon roll, c...  ...  ZGIdZ3y7kHsGssdrO8mZAQ
# ...                                                   ...  ...                     ...
# 499995  One of the most relaxing activities you can th...  ...  0gtEsazPeHr5rj2IAsZePg
# 499996  85 DEGREES IN APARTMENT MID SUNMER! For the pa...  ...  YESB_Rjy7RvzoAmvmC5-Zg
# 499997  This isn't the best dessert place, but one of ...  ...  vj2RoqU4nRFG0YLbTG4etw
# 499998  I ordered flowers online in the morning and th...  ...  TPhPLW6KXq-Avu6WS6rjGg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   review   500000 non-null  object
#  1   ratings  500000 non-null  float64
#  2   user_id  500000 non-null  object
# dtypes: float64(1), object(2)
# memory usage: 11.4+ MB

# %%
import string

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_of_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df["cleaned_reviews"] = df["review"].apply(lambda x : x.lower())

# %%
df["cleaned_reviews"] = df["cleaned_reviews"].apply(lambda x : ''.join([i for i in x if i not in string.punctuation]))

# %%
df["cleaned_reviews"] = df["cleaned_reviews"].apply(lambda x: ' '.join([i for i in x.split() if i not in stop_of_words]))

# %%
frequent_words = list(pd.Series(' '.join(df["cleaned_reviews"]).split()).value_counts()[:15].index)
#top 15 rare words
rare_words = list(pd.Series(' '.join(df["cleaned_reviews"]).split()).value_counts()[-15:].index)

# %%
df["cleaned_reviews"] = df["cleaned_reviews"].apply(lambda x: ' '.join([i for i in x.split() if i not in frequent_words]))

# %%
df["cleaned_reviews"] = df["cleaned_reviews"].apply(lambda x: ' '.join([i for i in x.split() if i not in rare_words]))

# %%
# !pip install textblob

# %%
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
import textblob
ps = PorterStemmer() 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df["cleaned_reviews"] = df["cleaned_reviews"].apply(lambda x: ' '.join(word_tokenize(str(x))))

# %%
df["user_id"] = df["user_id"].apply(lambda x : x.lower())

# %%
df.head(10)
# Out:
#                                               review  ...                                    cleaned_reviews
# 0  Awesome service and fantastic food, the wait s...  ...  awesome fantastic wait staff friendly accommod...
# 1  Seemed pretty pricey to me for what you got......  ...  seemed pretty pricey gotburgers tasted pretty ...
# 2  We TRIED to go to the buffet on Tuesday eve fo...  ...  tried buffet tuesday eve dinner found closed m...
# 3  Came here for lunch on my 20th birthday and th...  ...  came lunch 20th birthday gave free dessert sig...
# 4  Amazing treats - I love their cinnamon roll, c...  ...  amazing treats love cinnamon roll cupcakes ice...
# 5  Me and my family went to TasteBuds tonight..I ...  ...  family went tastebuds tonighti love begin went...
# 6  Stay away from this train wreck of a hospital ...  ...  stay away train wreck hospital er unprofession...
# 7  I have now had two amazing meals here and can'...  ...  two amazing meals cant wait return steaks lobs...
# ...

# %% [markdown]
# ##**MODELS**

# %%
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from nltk.tokenize import RegexpTokenizer

# %%
data_txs = df["cleaned_reviews"].values
reviews_data1 = [i.split() for i in data_txs]
reviews_data1 = reviews_data1[:500]
reviews1 = reviews_data1[:500]

# %%
bigram1 = gensim.models.Phrases(reviews_data1, min_count=5, threshold=100)
bigram_phaser1 = gensim.models.phrases.Phraser(bigram1)
trigram1 = gensim.models.Phrases(bigram1['vocab'], threshold=100)  
trigram_phaser1 = gensim.models.phrases.Phraser(trigram1)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/phrases.py:598: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
def make_bigrams(ip):
    return [bigram_phaser1[t] for t in ip]
def make_trigrams(ip):
    return [trigram_phaser1[bigram_phaser1[t]] for t in ip]

# %%
bigrams1 = make_bigrams(reviews_data1)
trigrams1=make_trigrams(bigrams1)

# %%
id2wrd1 = corpora.Dictionary(trigrams1)

# %%
corpus1 = [id2wrd1.doc2bow(i) for i in trigrams1]

# %%
lda_model1 = gensim.models.ldamodel.LdaModel(corpus=corpus1,
                                           id2word=id2wrd1,
                                           num_topics=20, 
                                           random_state=100)
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /usr/local/lib/python3.6/dist-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
# ...

# %%
res = lda_model1.print_topics()
for i in res:
  print(i)
# Out:
# (0, '0.006*"best" + 0.005*"im" + 0.005*"room" + 0.004*"people" + 0.004*"ive" + 0.004*"ever" + 0.004*"well" + 0.004*"definitely" + 0.003*"still" + 0.003*"dont"')
# (1, '0.007*"didnt" + 0.005*"car" + 0.005*"dont" + 0.004*"staff" + 0.004*"definitely" + 0.004*"well" + 0.004*"nice" + 0.004*"think" + 0.004*"love" + 0.004*"ever"')
# (2, '0.008*"got" + 0.006*"nice" + 0.005*"im" + 0.004*"made" + 0.004*"people" + 0.004*"work" + 0.004*"pizza" + 0.004*"well" + 0.004*"delicious" + 0.004*"around"')
# (3, '0.007*"restaurant" + 0.005*"nice" + 0.004*"made" + 0.004*"well" + 0.004*"meal" + 0.004*"staff" + 0.003*"try" + 0.003*"store" + 0.003*"ive" + 0.003*"table"')
# (4, '0.006*"going" + 0.005*"well" + 0.005*"got" + 0.004*"even" + 0.004*"went" + 0.004*"come" + 0.004*"definitely" + 0.004*"friendly" + 0.004*"way" + 0.003*"didnt"')
# (5, '0.007*"lunch" + 0.006*"best" + 0.005*"staff" + 0.005*"delicious" + 0.005*"always" + 0.004*"came" + 0.004*"sweet" + 0.004*"meat" + 0.004*"definitely" + 0.004*"eat"')
# ...

# %%
# !pip install pyLDAvis

# %%
# %matplotlib inline
import pyLDAvis
import pyLDAvis.gensim
vis = pyLDAvis.gensim.prepare(topic_model=lda_model1, corpus=corpus1, dictionary=id2wrd1)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el561400606716141925276977736"></div>
# <script type="text/javascript">
#
# ...

# %% [markdown]
# #**HMM - LDA**

# %%
#cloned the git code which is in git
# !git clone https://github.com/dongwookim-ml/python-topic-model.git
# Out:
# Cloning into 'python-topic-model'...
# remote: Enumerating objects: 357, done.
# remote: Total 357 (delta 0), reused 0 (delta 0), pack-reused 357
# Receiving objects: 100% (357/357), 18.75 MiB | 8.98 MiB/s, done.
# Resolving deltas: 100% (181/181), done.

# %%
#renamed the folder to ptm and ptm is sub folder present in the folder

# %%
import ptm

# %%
from ptm.ptm import hmm_lda

# %%
os.listdir()
# Out:
# ['.config', 'python-topic-model', '.ipynb_checkpoints', 'drive', 'ptm', 'Assignment four data Yelp (question 1 and 2).zip', 'Assignment four data Yelp (question 1 and 2)', 'logs', 'sample_data']

# %%
os.listdir('python-topic-model')
# Out:
# ['.gitignore', 'setup.py', '.git', 'notebook', 'data', 'LICENSE', 'ptm', 'README.md']

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
[name for name in pkgutil.iter_modules(['ptm'])]
# Out:
# [ModuleInfo(module_finder=FileFinder('ptm'), name='ptm', ispkg=True), ModuleInfo(module_finder=FileFinder('ptm'), name='setup', ispkg=False)]

# %%
topics = 20
number_of_classes = 20
from ptm.ptm.nltk_corpus import get_ids_cnt
from ptm.ptm.utils import convert_cnt_to_list
nltk.download('words')
model2 = hmm_lda.HMM_LDA(n_docs=10, n_voca=15000, n_topic = topics, n_class= number_of_classes, alpha=0.1, beta=0.01, gamma=0.1, eta=0.1, verbose=False)

data = df["review"].head(500).values
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import json
corpus = list()
counter = 0
for file in files:
  with open('/content/Assignment four data Yelp (question 1 and 2)/'+file,encoding='utf-8') as data:
    json_ip = json.load(data)
    counter += 1
    reviews=list()
    ratings=list()
    user_ids=list()
    for i in json_ip:
      reviews.append(i['text'])
      ratings.append(i['stars'])
      user_ids.append(i['user_id'])
  vocabulary, id2words, count_of_words = get_ids_cnt(reviews)
  corpus.append(convert_cnt_to_list(id2words, count_of_words))
  if(counter==50):
    break

# %%
try:
  model2.fit(corpus,max_iter=5)
except:
  pass

# %%
print("The topics are:\n\n")



for index in range(20):
  try:
    top_words = get_top_words(model2.TW, vocab=vocabulary,topic=index, n_words=10)
    print(top_words)
  except:
    pass
# Out:
# The topics are:
#
#
# ['menu' 'freeway' 'table' 'like' 'dessert' 'right' 'restaurant' 'one'
#  'next' 'seen']
# ['back' 'busy' 'really' 'upon' 'work' 'nice' 'well' 'consider' 'show'
#  'weekend']
# ['want' 'would' 'point' 'never' 'came' 'chicken' 'works' 'waiting' 'table'
#  'past']
# ['got' 'amazing' 'portion' 'like' 'added' 'need' 'sundae' 'pho' 'mostly'
#  'brittle']
# ['told' 'taste' 'know' 'really' 'one' 'glass' 'away' 'meal' 'additionally'
#  'think']
# ['told' 'overall' 'possibly' 'three' 'johnny' 'meal' 'serenity' 'think'
#  'must' 'favorite']
# ['like' 'said' 'told' 'order' 'got' 'took' 'behind' 'plentiful' 'clean'
#  'pork']
# ['people' 'two' 'station' 'new' 'dessert' 'meal' 'yummy' 'get' 'eat'
#  'future']
# ['one' 'would' 'corn' 'best' 'ate' 'waitress' 'everything' 'menu' 'work'
#  'favorite']
# ['one' 'made' 'top' 'area' 'chopped' 'restaurant' 'line' 'big' 'support'
#  'meet']
# ['great' 'every' 'root' 'home' 'taste' 'ordered' 'one' 'super' 'spot'
#  'orleans']
# ...

# %% [markdown]
# #**Question 2: Yelp Review Sentiment Analysis**
#
#
# (30 points). Sentiment analysis also known as opinion mining is a sub field within Natural Language Processing (NLP) that builds machine learning algorithms to classify a text according to the sentimental polarities of opinions it contains, e.g., positive, negative, neutral. The purpose of this question is to develop a machine learning classifier for sentiment analysis. Based on the dataset from assignment three, write a python program to implement a sentiment classifier and evaluate its performance. Notice: 80% data for training and 20% data for testing.
#
#
#
# The data can be download from Dropbox: https://www.dropbox.com/s/59hsrk56sfwh9u2/Assignment%20four%20data%20Yelp%20%28question%201%20and%202%29.zip?dl=0
#
# The data was saved in json format, here is an example of the data (for this task, you only need to use the star rating and the review text fields):
#
# { // string, 22 character unique review id "review_id": "zdSx_SD6obEhz9VrW9uAWA",
#
# // string, 22 character unique user id, maps to the user in user.json
# "user_id": "Ha3iJu77CxlrFm-vQRs_8g",
#
# // string, 22 character business id, maps to business in business.json
# "business_id": "tnhfDv5Il8EaGSXZGiuQGg",
#
# // integer, star rating
# "stars": 4,
#
# // string, date formatted YYYY-MM-DD
# "date": "2016-03-09",
#
# // string, the review itself
# "text": "Great place to hang out after work: the prices are decent, and the ambience is fun. It's a bit loud, but very lively. The staff is friendly, and the food is good. They have a good selection of drinks.",
#
# // integer, number of useful votes received
# "useful": 0,
#
# // integer, number of funny votes received
# "funny": 0,
#
# // integer, number of cool votes received
# "cool": 0
# }
#
# The sentiment of can be accessed based on the star rating, if no star information avaliable for a record, just remove that record. Detail star and sentiment level can be matched blew:
#
# Very positive = 5 stars
#
# Positive = 4 stars
#
# Neutral = 3 stars
#
# Negative = 2 stars
#
# Very negative = 1 star
#
# Here is code for yelp data preprocessing: https://github.com/Yelp/dataset-examples.
#
# Answer the following questions:
#
# (1) Features used for sentiment classification and explain why you select these features (tf-idf, sentiment lexicon, word2vec, etc). Considering achieve the best performance as you can.
#
# (2) Select two of the supervised learning algorithm from scikit-learn library: https://scikit-learn.org/stable/supervised_learning.html#supervised-learning, to build a sentiment classifier respectively.
#
# (3) Compare the performance over accuracy, precision, recall, and F1 score for the two algorithms you selected. Here is the reference of how to calculate these metrics: https://towardsdatascience.com/accuracy-precision-recall-or-f1-331fb37c5cb9.

# %%
import json
reviews = list()
ratings = list()
user_ids = list()
sentiments = list()
for file in files:
  with open('/content/Assignment four data Yelp (question 1 and 2)/'+file,encoding='utf-8') as data:
    json_ip = json.load(data)
    for i in json_ip:
      reviews.append(i['text'])
      val = "Positive"
      if(i['stars']==5):
        val = "Very Positive"
      elif(i['stars']==4):
        val = "Positive"
      elif(i['stars']==3):
        val = "Neutral"
      elif(i['stars']==2):
        val = "Negative"
      else:
        val = "Very Negative"
      sentiments.append(val)
      ratings.append(i['stars'])
      user_ids.append(i['user_id'])

# %%
df['sentiments'] = sentiments

# %%
df
# Out:
#                                                    review  ...     sentiments
# 0       Awesome service and fantastic food, the wait s...  ...  Very Positive
# 1       Seemed pretty pricey to me for what you got......  ...       Negative
# 2       We TRIED to go to the buffet on Tuesday eve fo...  ...  Very Negative
# 3       Came here for lunch on my 20th birthday and th...  ...  Very Positive
# 4       Amazing treats - I love their cinnamon roll, c...  ...  Very Positive
# ...                                                   ...  ...            ...
# 499995  One of the most relaxing activities you can th...  ...       Positive
# 499996  85 DEGREES IN APARTMENT MID SUNMER! For the pa...  ...  Very Negative
# 499997  This isn't the best dessert place, but one of ...  ...       Negative
# 499998  I ordered flowers online in the morning and th...  ...  Very Positive
# 499999  They have really good New York egg rolls. The ...  ...  Very Negative
#
# [500000 rows x 5 columns]

# %% [markdown]
# #**Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
decisionTreeClassifier = DecisionTreeClassifier()

# %%
res1 = df.head(100).reset_index()
from sklearn.feature_extraction.text import TfidfVectorizer
#display the vocabulary
vectorizer = TfidfVectorizer(analyzer='word')
tf_idf = vectorizer.fit_transform(res1["cleaned_reviews"].values)

# %%
list_of_column_names = vectorizer.get_feature_names()
tf_idf_df = pd.DataFrame(tf_idf.toarray())
tf_idf_df.columns = list_of_column_names

# %%
from sklearn.model_selection import train_test_split,cross_val_score,KFold
x_train, x_test, y_train, y_test = train_test_split(tf_idf_df, res1['sentiments'].values,test_size=0.2)

# %%
decisionTreeClassifier_model = decisionTreeClassifier.fit(x_train,y_train)

# %%
training_tf_idf_data = vectorizer.transform(res1["cleaned_reviews"])

# %%
decisionTreeClassifier_model = decisionTreeClassifier.fit(x_train,y_train)

# %%
y_op_decisionTreeClassifier = decisionTreeClassifier_model.predict(x_test)

# %%
y_op_decisionTreeClassifier
# Out:
# array(['Very Positive', 'Very Positive', 'Very Positive', 'Very Positive',
#        'Very Positive', 'Neutral', 'Very Positive', 'Very Positive',
#        'Very Positive', 'Very Positive', 'Very Positive', 'Positive',
#        'Very Positive', 'Very Negative', 'Very Positive', 'Very Positive',
#        'Very Positive', 'Very Positive', 'Very Positive', 'Very Positive'],
#       dtype=object)

# %% [markdown]
# #**Metrics**

# %%
from sklearn.metrics import accuracy_score,classification_report
print("Accuracy score ",round(accuracy_score(y_op_decisionTreeClassifier,y_test)*100,2))
print("---------------------------------------------------------------------------------")

print(classification_report(y_op_decisionTreeClassifier,y_test))
# Out:
# Accuracy score  45.0
# ---------------------------------------------------------------------------------
#                precision    recall  f1-score   support
#
#      Negative       0.00      0.00      0.00         0
#       Neutral       0.00      0.00      0.00         1
#      Positive       0.12      1.00      0.22         1
# Very Negative       0.00      0.00      0.00         1
# Very Positive       1.00      0.47      0.64        17
#
#      accuracy                           0.45        20
#     macro avg       0.23      0.29      0.17        20
#  weighted avg       0.86      0.45      0.56        20
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #**XG BOOST**

# %%
from xgboost import XGBClassifier
xgbClassifier = XGBClassifier()

# %%
xgbClassifier_model = xgbClassifier.fit(x_train,y_train)

# %%
y_op_xgbClassifier= xgbClassifier_model.predict(x_test)

# %%
op1 = pd.DataFrame(tf_idf.toarray())
op1.columns = vectorizer.get_feature_names()

# %%
y_op_xgbClassifier
# Out:
# array(['Very Positive', 'Very Positive', 'Very Positive', 'Positive',
#        'Very Positive', 'Very Positive', 'Very Positive', 'Very Positive',
#        'Negative', 'Very Positive', 'Very Positive', 'Very Negative',
#        'Very Positive', 'Very Negative', 'Very Positive', 'Very Positive',
#        'Very Positive', 'Very Positive', 'Very Positive', 'Very Positive'],
#       dtype=object)

# %% [markdown]
# #**Metrics**

# %%
from sklearn.metrics import accuracy_score,classification_report
print("Accuracy score ",round(accuracy_score(y_op_xgbClassifier,y_test)*100,2))
print("---------------------------------------------------------------------------------")

print(classification_report(y_op_xgbClassifier,y_test))
# Out:
# Accuracy score  35.0
# ---------------------------------------------------------------------------------
#                precision    recall  f1-score   support
#
#      Negative       0.00      0.00      0.00         1
#       Neutral       0.00      0.00      0.00         0
#      Positive       0.00      0.00      0.00         1
# Very Negative       0.00      0.00      0.00         2
# Very Positive       0.88      0.44      0.58        16
#
#      accuracy                           0.35        20
#     macro avg       0.17      0.09      0.12        20
#  weighted avg       0.70      0.35      0.47        20
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #**Question 3: House price prediction**
#
#
# (40 points). You are required to build a regression model to predict the house price with 79 explanatory variables describing (almost) every aspect of residential homes. The purpose of this question is to practice regression analysis, an supervised learning model. The training data, testing data, and data description files can be download from Dropbox: https://www.dropbox.com/s/52j9hpxppfo921o/assignment4-question3-data.zip?dl=0. Here is an axample for the implementation: https://towardsdatascience.com/linear-regression-in-python-predict-the-bay-areas-home-price-5c91c8378878.

# %%
train = pd.read_csv("/content/train.csv").dropna(axis=1)

# %%
train
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType SaleCondition SalePrice
# 0        1          60       RL  ...        WD        Normal    208500
# 1        2          20       RL  ...        WD        Normal    181500
# 2        3          60       RL  ...        WD        Normal    223500
# 3        4          70       RL  ...        WD       Abnorml    140000
# 4        5          60       RL  ...        WD        Normal    250000
# ...    ...         ...      ...  ...       ...           ...       ...
# 1455  1456          60       RL  ...        WD        Normal    175000
# 1456  1457          20       RL  ...        WD        Normal    210000
# 1457  1458          70       RL  ...        WD        Normal    266500
# 1458  1459          20       RL  ...        WD        Normal    142125
# 1459  1460          20       RL  ...        WD        Normal    147500
#
# [1460 rows x 62 columns]

# %%
test = pd.read_csv("/content/test.csv").dropna(axis=1)

# %%
test["SalePrice"] = 0

# %%
test
# Out:
#         Id  MSSubClass  LotArea Street  ... MoSold YrSold SaleCondition SalePrice
# 0     1461          20    11622   Pave  ...      6   2010        Normal         0
# 1     1462          20    14267   Pave  ...      6   2010        Normal         0
# 2     1463          60    13830   Pave  ...      3   2010        Normal         0
# 3     1464          60     9978   Pave  ...      6   2010        Normal         0
# 4     1465         120     5005   Pave  ...      1   2010        Normal         0
# ...    ...         ...      ...    ...  ...    ...    ...           ...       ...
# 1454  2915         160     1936   Pave  ...      6   2006        Normal         0
# 1455  2916         160     1894   Pave  ...      4   2006       Abnorml         0
# 1456  2917          20    20000   Pave  ...      9   2006       Abnorml         0
# 1457  2918          85    10441   Pave  ...      7   2006        Normal         0
# ...

# %%
l1 = train.columns.tolist()
l2 = test.columns.tolist()

# %%
final_list = list()
for i in l1:
  if i in l2:
    final_list.append(i)

# %%
final_df = pd.concat([train[final_list],test[final_list]],axis=0)

# %%
final_df
# Out:
#         Id  MSSubClass  LotArea Street  ... MoSold YrSold SaleCondition SalePrice
# 0        1          60     8450   Pave  ...      2   2008        Normal    208500
# 1        2          20     9600   Pave  ...      5   2007        Normal    181500
# 2        3          60    11250   Pave  ...      9   2008        Normal    223500
# 3        4          70     9550   Pave  ...      2   2006       Abnorml    140000
# 4        5          60    14260   Pave  ...     12   2008        Normal    250000
# ...    ...         ...      ...    ...  ...    ...    ...           ...       ...
# 1454  2915         160     1936   Pave  ...      6   2006        Normal         0
# 1455  2916         160     1894   Pave  ...      4   2006       Abnorml         0
# 1456  2917          20    20000   Pave  ...      9   2006       Abnorml         0
# 1457  2918          85    10441   Pave  ...      7   2006        Normal         0
# ...

# %%
test = final_df.head(1)
string_values = list()
numeric_values = list()
for i in test.columns:
  if(type(test[i].values[0])== str):
    string_values.append(i)
  else:
    numeric_values.append(i)

# %%
temp = pd.get_dummies(final_df[string_values],columns=string_values)

# %%
final_df = pd.concat([temp,final_df[numeric_values]],axis=1)

# %%
final_df
# Out:
#       Street_Grvl  Street_Pave  LotShape_IR1  ...  MoSold  YrSold  SalePrice
# 0               0            1             0  ...       2    2008     208500
# 1               0            1             0  ...       5    2007     181500
# 2               0            1             1  ...       9    2008     223500
# 3               0            1             1  ...       2    2006     140000
# 4               0            1             1  ...      12    2008     250000
# ...           ...          ...           ...  ...     ...     ...        ...
# 1454            0            1             0  ...       6    2006          0
# 1455            0            1             0  ...       4    2006          0
# 1456            0            1             0  ...       9    2006          0
# 1457            0            1             0  ...       7    2006          0
# 1458            0            1             0  ...      11    2006          0
#
# [2919 rows x 151 columns]

# %%
list_of_values = final_df.values

x = list_of_values[:,1:150]
y = final_df["SalePrice"].values.tolist()

# %% [markdown]
# #I observed there is 50% training ans 50% testing data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.5, random_state = 5)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
result = model.predict(x_test)

# %%
result
# Out:
# array([264515.1328125, 193811.8828125, 243846.96875  , ...,
#        176983.96875  , 141266.34375  ,  67111.3359375])

# %%
print("The average mean of prediction ", result.mean())
# Out:
# The average mean of prediction  308816.1640250428

# %%
result.tolist()
# Out:
# [264515.1328125,
#  193811.8828125,
#  243846.96875,
#  158542.1328125,
#  154793.96875,
#  2469.375,
#  154465.2109375,
#  8247.546875,
#  70654.9609375,
#  -3886.703125,
#  -33080.9921875,
#  104075.796875,
#  210753.9609375,
#  184344.34375,
#  110624.7109375,
#  -43874.03125,
#  -1084.03125,
#  57672.7109375,
#  21941.296875,
#  169329.1328125,
#  72159.4609375,
#  130498.8359375,
#  178543.6328125,
#  40878.7109375,
#  172871.1328125,
#  114437.1328125,
#  90462.7109375,
#  141906.96875,
#  26683.125,
#  108380.5,
#  102117.4609375,
#  105220.375,
#  179744.46875,
#  249641.421875,
#  195070.96875,
#  14725.125,
#  149776.8828125,
#  170723.6328125,
#  -25647.9921875,
#  313590.8828125,
#  163268.171875,
#  24377.296875,
#  -18863.703125,
#  153005.2109375,
#  28511.171875,
#  9132.2109375,
#  3029.34375,
#  94896.0859375,
#  56244.3359375,
#  144773.625,
#  109356.59375,
#  21776.671875,
#  315624.7109375,
#  4039.4609375,
#  197856.3828125,
#  18633.875,
#  162957.4609375,
# ...
