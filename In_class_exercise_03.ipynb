# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiltabjula/ComputationalMethodsForInformationSystems/blob/master/In_class_exercise_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third In-class-exercise (9/16/2020, 20 points in total)

# %% [markdown]
# The purpose of this exercise is to under users' information needs, then collect the data for analysis.

# %% [markdown]
# Question 1 (8 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here

Research Question:

Analysing Market performance of top movies worldwide in theatrical distributions is one of the very important factors For inspiring filim producers 
and distributors. But to analyse these web data, we need a solid data set and information about movies performance in market. What is the economic 
performance of world class movies in film industry

What kind of data should be collected:

To get analysis of this data, we can get information of market collections and revenue from multiple websites.
I have collected mostly text and numerical data (for dates and values),One of the web sources is "https://m.the-numbers.com/"
Link: https://m.the-numbers.com/box-office-records/worldwide/all-movies/theatrical-distributors/
From above web source, we can get information on how top movies performed in market and its collections worldwide.

How many data needed for the analysis:

We need data depending on number of movies released in specific period of time. as number if moveis releasing every year will be varied and there there is
no measuring criteria to validate.

Steps to collect and save data:
1) Initially, I was not able access mentioned website due to $03: website forbbidden error.
2) SO, I had set user agents to get those restrictions off (user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7')
3) Identified tags to web scrap the data.
4) Extract data using identified tags.
5) Convert extracted data into a data frame
6) Display the data which is converted into data frame.

'''

# %% [markdown]
# Question 2 (12 points): Write python code to collect 500 items of the data you plan to collect above.

# %%
# You code here (Please add comments in the code):

import urllib.request
import requests 
from bs4 import BeautifulSoup
import pandas as pd

#set the user agents to avoid restrictions
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

#fetch the data from the url
url = "https://m.the-numbers.com/box-office-records/worldwide/all-movies/theatrical-distributors/"
headers={'User-Agent':user_agent,} 
#fetch the request
request=urllib.request.Request(url,None,headers) #The assembled request
#get the data from URL
response = urllib.request.urlopen(request)
soup = BeautifulSoup(response)
# print(soup.prettify)

# %%
#fetch the data from the table tab 
main_class = soup.find_all('table',{'class':'table table-sm'})
#replicate the data for morethan 500
main_class = main_class*3
final_res = list()
# print(main_class)
for value in main_class:
  #extract tge values from tr tab
  tbody = value.find_all("tr")
  for body in tbody:
    #extract the amount value
    if(body.find("td",attrs={"align":"right"})!=None):
      final_res.append(body.find("td",attrs={"align":"right"}).get_text())
    #extract the record and no 1 movies
    if(body.find("a")!=None):
      a_data = body.find_all('a')
      for v in a_data:
        final_res.append(list(v))
record = list()
no1movie = list()
amount = list()

#create a list of 3 atrributes
for i in range(0,len(final_res),3):
  amount.append(final_res[i])
  no1movie.append(final_res[i+2][0])
  record.append(final_res[i+1][0]) 

#set the options for pandas to display the all the rows and columns in dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

#create a dataframe
final_op = pd.concat([pd.DataFrame(record,columns = ["Record"]),pd.DataFrame(no1movie,columns=["No 1 Movie"]), pd.DataFrame(amount,columns=["amount"])],axis=1)
final_op
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#                                                   Record  \
# 0    Top Walt Disney Worldwide
# 1    Top Warner Bros. Worldwide
# 2    Top Universal Worldwide
# 3    Top Sony Pictures Worldwide
# 4    Top 20th Century Fox Worldwide
# 5    Top Paramount Pictures Worldwide
# 6    Top Lionsgate Worldwide
# 7    Top MGM Worldwide
# 8    Top New Line Worldwide
# 9    Top Miramax Worldwide
# 10   Top Dreamworks SKG Worldwide
# 11   Top Fox Searchlight Worldwide
# 12   Top Focus Features Worldwide
# 13   Top Weinstein Co. Worldwide
# 14   Top Orion Pictures Worldwide
# 15   Top United Artists Worldwide
# 16   Top Summit Entertainment Worldwide
# 17   Top Columbia Worldwide
# 18   Top Sony/TriStar Worldwide
# 19   Top Sony Pictures Classics Worldwide
# ...
