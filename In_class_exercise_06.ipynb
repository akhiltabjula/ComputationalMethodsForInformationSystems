# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiltabjula/ComputationalMethodsForInformationSystems/blob/master/In_class_exercise_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The sixth in-class-exercise (20 points in total, 10/14/2020)**

# %% [markdown]
# ## **1. Rule-based information extraction (10 points)**
#
# Use any keywords related to data science, natural language processing, machine learning to search from google scholar, get the **titles** of 100 articles (either by web scraping or manually) about this topic, define a set of patterns to extract the research questions/problems, methods/algorithms/models, datasets, applications, or any other important information about this topic.

# %%
import pandas as pd
res = pd.read_csv("/content/Titles_data.csv")
res
# Out:
#                                                Titles
# 0                           Principles of data mining
# 1                      Privacy-preserving data mining
# 2                Data mining: concepts and techniques
# 3                    Data preparation for data mining
# 4                         Untangling text data mining
# 5              Data mining applications in healthcare
# 6                              Relational data mining
# 7             Data warehousing, data mining, and OLAP
# 8                           Data mining with big data
# 9   Discovering knowledge in data: an introduction...
# 10                   Top 10 algorithms in data mining
# 11           The WEKA data mining software: an update
# 12       Data mining and knowledge discovery handbook
# 13  From data mining to knowledge discovery in dat...
# 14  Data mining: practical machine learning tools ...
# 15      A survey of clustering data mining techniques
# ...

# %%
import spacy 
from spacy.matcher import Matcher 
from spacy.tokens import Span 
from spacy import displacy 

nlp = spacy.load("en_core_web_sm")

# %%
import re

# %%
def return_empty_list():
  return list()

# %%
reg1 = "[^.!?;]*(?:for)[^.!?;]*" #extract the values that start with Methods or Methods
a = return_empty_list()
for i in res["Titles"]:
  val1 = re.findall(reg1,i)
  if(len(val1)>0):
    a.append(val1)
print(a)
# Out:
# [['Data preparation for data mining'], ['Data mining for education'], ['Information visualization and visual data mining'], ['Data mining approaches for intrusion detection'], ['Automatic subspace clustering of high dimensional data for data mining applications'], ['Feature selection for knowledge discovery and data mining'], ['Data mining in bioinformatics using Weka'], ['Tools for privacy preserving distributed data mining'], ['E cient and E ective clustering methods for spatial data mining'], ['SLIQ: A fast scalable classifier for data mining'], ['Data preparation for data mining'], ['Data mining for imbalanced datasets: An overview'], ['Secure multiparty computation for privacy preserving data mining'], ['Information visualization in data mining and knowledge discovery'], ["Mining educational data to analyze students' performance"], ['Bayesian networks for data mining'], ['Yale: Rapid prototyping for complex data mining tasks'], ['Data mining techniques: for marketing, sales, and
# ...

# %%
reg1 = "(.*):\s*([^,]+)" #extract the values that start with Methods or Methods
a = return_empty_list()
for i in res["Titles"]:
  val1 = re.findall(reg1,i)
  if(len(val1)!=0):
    a.append(val1)
print(a)
# Out:
# [[('Data mining', 'concepts and techniques')], [('Discovering knowledge in data', 'an introduction to data mining')], [('The WEKA data mining software', 'an update')], [('Data mining', 'practical machine learning tools and techniques with Java implementations')], [('Mastering data mining', 'The art and science of customer relationship management')], [('Predictive data mining', 'a practical guide')], [('Data mining', 'an overview from a database perspective')], [('Data mining', 'Introductory and advanced topics')], [('Data mining', 'the textbook')], [('Data mining', 'a tutorial-based primer')], [('Data mining with decision trees', 'theory and applications')], [('Educational data mining', 'A survey from 1995 to 2005')], [('Data mining', 'concepts')], [('SLIQ', 'A fast scalable classifier for data mining')], [('The elements of statistical learning', 'data mining')], [('Data mining for imbalanced datasets', 'An overview')], [('Knowledge Discovery and Data Mining', 'Towards a Unifying Fra
# ...

# %%
#starts with data mining
op1 = res['Titles'].str.startswith("Data",na=False)
res[op1]
# Out:
#                                                Titles
# 2                Data mining: concepts and techniques
# 3                    Data preparation for data mining
# 5              Data mining applications in healthcare
# 7             Data warehousing, data mining, and OLAP
# 8                           Data mining with big data
# 12       Data mining and knowledge discovery handbook
# 14  Data mining: practical machine learning tools ...
# 21  Data mining: an overview from a database persp...
# 22                          Data mining for education
# 24      Data mining: Introductory and advanced topics
# 25                             Data mining techniques
# 26                Data mining and knowledge discovery
# 27                          Data mining: the textbook
# 31     Data mining approaches for intrusion detection
# 32  Data mining with an ant colony optimization al...
# 35               Data mining: a tutorial-based primer
# ...

# %%
#contains data mining
op1 = res['Titles'].str.contains("Data mining",na=False)
res[op1]
# Out:
#                                                Titles
# 2                Data mining: concepts and techniques
# 5              Data mining applications in healthcare
# 8                           Data mining with big data
# 12       Data mining and knowledge discovery handbook
# 14  Data mining: practical machine learning tools ...
# 21  Data mining: an overview from a database persp...
# 22                          Data mining for education
# 24      Data mining: Introductory and advanced topics
# 25                             Data mining techniques
# 26                Data mining and knowledge discovery
# 27                          Data mining: the textbook
# 31     Data mining approaches for intrusion detection
# 32  Data mining with an ant colony optimization al...
# 35               Data mining: a tutorial-based primer
# 38  Data mining with decision trees: theory and ap...
# 42           Data mining in bioinformatics using Weka
# ...

# %%
#contains statistics
op1 = res['Titles'].str.contains("statistics",na=False)
res[op1]
# Out:
#                                Titles
# 84  Data mining: statistics and more?

# %%
res1 = res["Titles"].tolist()
result = list()
for i in res1:
  j = nlp(i)
  for k in j:
    result.append([k.text,k.pos_])
print(result)
# Out:
# [['Principles', 'NOUN'], ['of', 'ADP'], ['data', 'NOUN'], ['mining', 'NOUN'], ['Privacy', 'NOUN'], ['-', 'PUNCT'], ['preserving', 'VERB'], ['data', 'NOUN'], ['mining', 'NOUN'], ['Data', 'NOUN'], ['mining', 'NOUN'], [':', 'PUNCT'], ['concepts', 'NOUN'], ['and', 'CCONJ'], ['techniques', 'NOUN'], ['Data', 'NOUN'], ['preparation', 'NOUN'], ['for', 'ADP'], ['data', 'NOUN'], ['mining', 'NOUN'], ['Untangling', 'VERB'], ['text', 'NOUN'], ['data', 'NOUN'], ['mining', 'NOUN'], ['Data', 'NOUN'], ['mining', 'NOUN'], ['applications', 'NOUN'], ['in', 'ADP'], ['healthcare', 'PROPN'], ['Relational', 'ADJ'], ['data', 'NOUN'], ['mining', 'NOUN'], ['Data', 'NOUN'], ['warehousing', 'NOUN'], [',', 'PUNCT'], ['data', 'NOUN'], ['mining', 'NOUN'], [',', 'PUNCT'], ['and', 'CCONJ'], ['OLAP', 'PROPN'], ['Data', 'NOUN'], ['mining', 'NOUN'], ['with', 'ADP'], ['big', 'ADJ'], ['data', 'NOUN'], ['Discovering', 'VERB'], ['knowledge', 'NOUN'], ['in', 'ADP'], ['data', 'NOUN'], [':', 'PUNCT'], ['an', 'DET'], ['introduc
# ...

# %% [markdown]
# ## **2. Domain-specific information extraction (10 points)**
#
# For the legal case used in the data cleaning exercise: [01-05-1 Adams v Tanner.txt](https://github.com/unt-iialab/INFO5731_FALL2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt), use [legalNLP](https://lexpredict-lexnlp.readthedocs.io/en/latest/modules/extract/extract.html#nlp-based-extraction-methods) to extract the following inforation from the text (if the information is not exist, just print None):
#
# (1) acts, e.g., “section 1 of the Advancing Hope Act, 1986”
#
# (2) amounts, e.g., “ten pounds” or “5.8 megawatts”
#
# (3) citations, e.g., “10 U.S. 100” or “1998 S. Ct. 1”
#
# (4) companies, e.g., “Lexpredict LLC”
#
# (5) conditions, e.g., “subject to …” or “unless and until …”
#
# (6) constraints, e.g., “no more than”
#
# (7) copyright, e.g., “(C) Copyright 2000 Acme”
#
# (8) courts, e.g., “Supreme Court of New York”
#
# (9) CUSIP, e.g., “392690QT3”
#
# (10) dates, e.g., “June 1, 2017” or “2018-01-01”
#
# (11) definitions, e.g., “Term shall mean …”
#
# (12) distances, e.g., “fifteen miles”
#
# (13) durations, e.g., “ten years” or “thirty days”
#
# (14) geographic and geopolitical entities, e.g., “New York” or “Norway”
#
# (15) money and currency usages, e.g., “$5” or “10 Euro”
#
# (16) percents and rates, e.g., “10%” or “50 bps”
#
# (17) PII, e.g., “212-212-2121” or “999-999-9999”
#
# (18) ratios, e.g.,” 3:1” or “four to three”
#
# (19) regulations, e.g., “32 CFR 170”
#
# (20) trademarks, e.g., “MyApp (TM)”
#
# (21) URLs, e.g., “http://acme.com/”
#
# (22) addresses, e.g., “1999 Mount Read Blvd, Rochester, NY, USA, 14615”
#
# (23) persons, e.g., “John Doe

# %%
# !pip install pysbd
# !pip install lexnlp==0.2.7
# !pip install -U nltk==3.2.4
# !pip install pyap
# Out:
# ...
# Requirement already up-to-date: nltk==3.2.4 in /usr/local/lib/python3.6/dist-packages (3.2.4)
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# !pip install lexnlp==0.2.7
# !pip install scipy
from lexnlp.extract.en.dict_entities import entity_config

# %%
# !pip install scipy==1.4.1
import pysbd
import pandas as pd
import lexnlp.extract.en.acts
import lexnlp.extract.en.citations
import lexnlp.extract.en.entities.nltk_re
import lexnlp.extract.en.conditions
import lexnlp.extract.en.constraints
import lexnlp.extract.en.copyright
import lexnlp.extract.en.courts
import lexnlp.extract.en.cusip
import lexnlp.extract.en.dates
import lexnlp.extract.en.definitions
import lexnlp.extract.en.distances
import lexnlp.extract.en.durations
import lexnlp.extract.en.geoentities
import lexnlp.extract.en.money
import lexnlp.extract.en.percents
import lexnlp.extract.en.pii
import lexnlp.extract.en.ratios
import lexnlp.extract.en.regulations
import lexnlp.extract.en.trademarks
import lexnlp.extract.en.urls
import lexnlp.extract.en.addresses
import pyap

# %%
# !wget 'https://nlp.stanford.edu/software/stanford-ner-2018-10-16.zip'
# !unzip stanford-ner-2018-10-16.zip
from zipfile import ZipFile
with ZipFile('stanford-ner-2018-10-16.zip', 'r') as zipObj:
   zipObj.extractall('/stanford')

import nltk
from nltk.tag.stanford import StanfordNERTagger
st = StanfordNERTagger('/stanford/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz', '/stanford/stanford-ner-2018-10-16/stanford-ner.jar')
# Out:
# --2020-10-16 02:55:36--  https://nlp.stanford.edu/software/stanford-ner-2018-10-16.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180358328 (172M) [application/zip]
# Saving to: ‘stanford-ner-2018-10-16.zip’
#
# stanford-ner-2018-1 100%[===================>] 172.00M  1.95MB/s    in 58s
#
# 2020-10-16 02:56:34 (2.97 MB/s) - ‘stanford-ner-2018-10-16.zip’ saved [180358328/180358328]
#
# Archive:  stanford-ner-2018-10-16.zip
#    creating: stanford-ner-2018-10-16/
#   inflating: stanford-ner-2018-10-16/README.txt
#   inflating: stanford-ner-2018-10-16/ner-gui.bat
#   inflating: stanford-ner-2018-10-16/build.xml
#   inflating: stanford-ner-2018-10-16/stanford-ner.jar
#   inflating: stanford-ner-2018-10-16/sample-conll-file.txt
#   inflating: stanford-ner-2018-10-16/sample.ner.txt
# ...

# %%
import string
with open ("/content/sample_data/test_data.txt", "r") as files:
      final_data=files.read()
      cleaned_data = final_data.translate(str.maketrans('', '', string.punctuation))
      res=cleaned_data.replace('\n',' ')

if len(list(lexnlp.extract.en.acts.get_act_list(res)))>0:
  print("Acts : ", lexnlp.extract.en.acts.get_act_list(res))
else:
  print("Acts : None")

if len(list(lexnlp.extract.en.amounts.get_amounts(res)))>0:
  print("Amounts : ", list(lexnlp.extract.en.amounts.get_amounts(res)))
else:
  print("Amounts : None")

if len(list(lexnlp.extract.en.citations.get_citations(res)))>0:
  print("Citations : ", list(lexnlp.extract.en.citations.get_citations(res)))
else:
  print("Citations : None")

if len(list(lexnlp.extract.en.entities.nltk_re.get_companies(res)))>0:
  print("Companies : ", list(lexnlp.extract.en.entities.nltk_re.get_companies(res)))
else:
  print("Companies : None")

if len(list(lexnlp.extract.en.conditions.get_conditions(res)))>0:
  print("Conditions : ", list(lexnlp.extract.en.conditions.get_conditions(res)))
else:
  print("Conditions : None")


if len(list(lexnlp.extract.en.constraints.get_constraints(res)))>0:
  print("Constraints : ", list(lexnlp.extract.en.constraints.get_constraints(res)))
else:
  print("Constraints : None")


if len(list(lexnlp.extract.en.copyright.get_copyright(res)))>0:
  print("Copyright : ", list(lexnlp.extract.en.copyright.get_copyright(res)))
else:
  print("Copyright : None")


values=[]
court_df = pd.read_csv("https://raw.githubusercontent.com/LexPredict/lexpredict-legal-dictionary/1.0.5/en/legal/us_courts.csv")
for _, row in court_df.iterrows():
  data= lexnlp.extract.en.dict_entities.entity_config(row["Court ID"], row["Court Name"], 0, row["Alias"].split(";") if not pd.isnull(row["Alias"]) else [])
  values.append(data)


for entity, alias in lexnlp.extract.en.courts.get_courts(res, values):
    print("Courts :", entity,alias)

if len(list(lexnlp.extract.en.cusip.get_cusip(res)))>0:
  print("CUSIP : ", list(lexnlp.extract.en.cusip.get_cusip(res)))
else:
  print("CUSIP : None")



if len(list(lexnlp.extract.en.dates.get_dates(res)))>0:
  print("Dates : ", list(lexnlp.extract.en.dates.get_dates(res)))
else:
  print("Dates : None")


if len(list(lexnlp.extract.en.definitions.get_definitions(res)))>0:
  print("Definition : ", list(lexnlp.extract.en.definitions.get_definitions(res)))
else:
  print("Definition : None")



if len(list(lexnlp.extract.en.distances.get_distances(res)))>0:
  print("Distance : ", list(lexnlp.extract.en.distances.get_distances(res)))
else:
  print("Distance : None")



if len(list(lexnlp.extract.en.durations.get_durations(res)))>0:
  print("Duration : ", list(lexnlp.extract.en.durations.get_durations(res)))
else:
  print("Duration : None")


for entity,alias in lexnlp.extract.en.geoentities.get_geoentities(res,values):
  print('geographic and geopolitical entities :',entity,alias)

if len(list(lexnlp.extract.en.money.get_money(res)))>0:
  print("Money : ", list(lexnlp.extract.en.money.get_money(res)))
else:
  print("Money : None")

if len(list(lexnlp.extract.en.percents.get_percents(res)))>0:
  print("Percents : ", list(lexnlp.extract.en.percents.get_percents(res)))
else:
  print("Percents : None")


if len(list(lexnlp.extract.en.pii.get_pii(res)))>0:
  print("PII : ", list(lexnlp.extract.en.pii.get_pii(res)))
else:
  print("PII : None")

if len(list(lexnlp.extract.en.ratios.get_ratios(res)))>0:
  print("Ratios : ", list(lexnlp.extract.en.ratios.get_ratios(res)))
else:
  print("Ratios : None")

if len(list(lexnlp.extract.en.regulations.get_regulations(res)))>0:
  print("Regulations : ", list(lexnlp.extract.en.regulations.get_regulations(res)))
else:
  print("Regulations : None")

if len(list(lexnlp.extract.en.trademarks.get_trademarks(res)))>0:
  print("Trademarks : ", list(lexnlp.extract.en.trademarks.get_trademarks(res)))
else:
  print("Trademarks : None")

if len(list(lexnlp.extract.en.urls.get_urls(res)))>0:
  print("URL : ", list(lexnlp.extract.en.urls.get_urls(res)))
else:
  print("URL : None")

addresses=pyap.parse(res, country='US')
final_address=list()
print("address")
for value in addresses:
  print(value)
# Out:
# Acts : None
# ...

# %%
val = list()
for sent in nltk.sent_tokenize(res): 
    tags = st.tag(nltk.tokenize.word_tokenize(sent))
    val = [tag[0] for tag in tags if tag[1]=='PERSON']
print("Persons", val)
# Out:
# Persons ['Lien', 'Allen', 'Harrison', 'Allen', 'Harrison', 'Harrison', 'Harrison', 'Burton', 'Harrison', 'Allen', 'Harrison', 'Harrison', 'Harrison', 'SMITH', 'Harrison', 'Harrison', 'Harrison', 'W', 'G', 'JONES', 'Perkins', 'Dane', 'Salk', 'Mansony', 'Gary', 'Hon', 'JOHN', 'D', 'CUNNINGHAM', 'Hon', 'JOHN', 'D', 'CUNNINGHAM', 'Jacob', 'S', 'Cohen', 'Cohen', 'Weakley']
